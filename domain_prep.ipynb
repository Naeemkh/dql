# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation

# from cube import Cube
# from agent import Agent
from domain import Domain
from util import create_random_domain

# %%
# domain
mydomain = Domain((10,10),"2D", 123)

mywall = []
mystorage = []
mygold=[]

mywall.extend([[i,3] for i in range(0,3)])
mywall.extend([[i,7] for i in range(2,6)])
mywall.extend([[8,j] for j in range(2,4)])

mygold.extend([[4,5]])

mystorage.extend([[0,4],[0,5],[1,4],[1,5]])

myagent = [[1,1]]

mydomain.build_domain([mywall, myagent, mystorage, mygold])

# %%
mydomain.get_state().shape
# Out:
# (3, 64, 64)

# %%
fig = plt.figure(2, figsize=(6, 6))
mydomain.plot_domain(True)

# %%
mydomain.action("Up")
# Out:
# (-0.05, False)

# %%
mydomain.plot_domain(True)

# %%
mydomain.reset()

# %%
mydomain.plot_domain(True)

# %%
action = 'Down'
for _ in range(3):
    reward = mydomain.action(action)
    print(f'reward and terminate: {reward}')
    fig = plt.figure(2, figsize=(6, 6))
    mydomain.plot_domain(True)
# Out:
# reward and terminate: (-0.05, False)
# reward and terminate: (-0.05, False)
# reward and terminate: (-0.05, False)

# %%
action = 'Right'
for _ in range(4):
    reward = mydomain.action(action)
    print(f'reward and terminate: {reward}')
    fig = plt.figure(2, figsize=(6, 6))
    mydomain.plot_domain(True)
# Out:
# reward and terminate: (-0.05, False)
# reward and terminate: (-0.05, False)
# reward and terminate: (-0.05, False)
# reward and terminate: (1.0, False)

# %%
action = 'Up'
for _ in range(3):
    reward = mydomain.action(action)
    print(f'reward and terminate: {reward}')
    fig = plt.figure(2, figsize=(6, 6))
    mydomain.plot_domain(True)
# Out:
# reward and terminate: (-0.05, False)
# reward and terminate: (-0.05, False)
# reward and terminate: (1.0, True)

# %%
mydomain.reset()

# %%
mydomain.plot_domain(True)

# %%
mydomain.reset(new_start_loc=True)

# %%
mydomain.plot_domain(True)
